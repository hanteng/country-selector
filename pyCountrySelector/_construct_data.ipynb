# %%
# -*- coding: utf-8 -*-
#歧視無邊，回頭是岸。鍵起鍵落，情真情幻。
dir_outcome = "data"
## Outpuing Lists
outputfn_locales = "locales_available.json"
outputfn_src_lc = "territories.json"
outputfn_JSON = "territories.json"
outputfn_HTML = "territories_snippet.htm"

import os.path, glob
import json
import requests
import icu # pip install PyICU

def url_request (url):
    r = requests.get(url)
    if r.status_code == 200:
        return r
    else:
        return None 


def load_json_list (lc_file, u):
    try:
        with open(lc_file, 'r', encoding="utf-8") as infile:
            _select = json.load (infile)
            print ("Loaded from local file.")
    except:
        results = url_request (url  = u)
        if results is not None:
            try:
                _select = results.json()['availableLocales']['full']
                with open(lc_file, 'w', encoding="utf-8") as outfile:
                    outfile.write("{}".format(_select).replace("'",'"'))
                print ("Loaded from designated url.")
            except:
                pass
    return _select

# Full Construction
URL_CLDR_JSON_AVAIL_LOCALES_LC = os.path.join ("..", dir_outcome, outputfn_locales)
URL_CLDR_JSON_AVAIL_LOCALES = "https://raw.githubusercontent.com/unicode-cldr/cldr-core/master/availableLocales.json"
locale_select = load_json_list (URL_CLDR_JSON_AVAIL_LOCALES_LC, URL_CLDR_JSON_AVAIL_LOCALES)

# %%
locale_select
# Out:
# ['af',
#  'af-NA',
#  'agq',
#  'ak',
#  'am',
#  'ar',
#  'ar-AE',
#  'ar-BH',
#  'ar-DJ',
#  'ar-DZ',
#  'ar-EG',
#  'ar-EH',
#  'ar-ER',
#  'ar-IL',
#  'ar-IQ',
#  'ar-JO',
#  'ar-KM',
#  'ar-KW',
#  'ar-LB',
#  'ar-LY',
#  'ar-MA',
#  'ar-MR',
#  'ar-OM',
#  'ar-PS',
#  'ar-QA',
#  'ar-SA',
#  'ar-SD',
#  'ar-SO',
#  'ar-SS',
#  'ar-SY',
#  'ar-TD',
#  'ar-TN',
#  'ar-YE',
#  'as',
#  'asa',
#  'ast',
#  'az',
#  'az-Cyrl',
#  'az-Latn',
#  'bas',
#  'be',
#  'bem',
#  'bez',
#  'bg',
#  'bm',
#  'bn',
#  'bn-IN',
#  'bo',
#  'bo-IN',
#  'br',
#  'brx',
#  'bs',
#  'bs-Cyrl',
#  'bs-Latn',
#  'ca',
#  'ca-AD',
#  'ca-ES-VALENCIA',
#  'ca-FR',
#  'ca-IT',
#  'ccp',
#  'ccp-IN',
#  'ce',
#  'cgg',
#  'chr',
#  'ckb',
#  'ckb-IR',
#  'cs',
#  'cu',
#  'cy',
#  'da',
#  'da-GL',
#  'dav',
#  'de',
#  'de-AT',
#  'de-BE',
#  'de-CH',
#  'de-IT',
#  'de-LI',
#  'de-LU',
#  'dje',
#  'dsb',
#  'dua',
#  'dyo',
#  'dz',
#  'ebu',
#  'ee',
#  'ee-TG',
#  'el',
#  'el-CY',
#  'en',
#  'en-001',
#  'en-150',
#  'en-AG',
#  'en-AI',
#  'en-AS',
#  'en-AT',
#  'en-AU',
#  'en-BB',
#  'en-BE',
#  'en-BI',
#  'en-BM',
#  'en-BS',
#  'en-BW',
#  'en-BZ',
#  'en-CA',
#  'en-CC',
#  'en-CH',
#  'en-CK',
#  'en-CM',
#  'en-CX',
#  'en-CY',
#  'en-DE',
#  'en-DG',
#  'en-DK',
#  'en-DM',
#  'en-ER',
#  'en-FI',
#  'en-FJ',
#  'en-FK',
#  'en-FM',
#  'en-GB',
#  'en-GD',
#  'en-GG',
#  'en-GH',
#  'en-GI',
#  'en-GM',
#  'en-GU',
#  'en-GY',
#  'en-HK',
#  'en-IE',
#  'en-IL',
#  'en-IM',
#  'en-IN',
#  'en-IO',
#  'en-JE',
#  'en-JM',
#  'en-KE',
#  'en-KI',
#  'en-KN',
#  'en-KY',
#  'en-LC',
#  'en-LR',
#  'en-LS',
#  'en-MG',
#  'en-MH',
#  'en-MO',
#  'en-MP',
#  'en-MS',
#  'en-MT',
#  'en-MU',
#  'en-MW',
#  'en-MY',
#  'en-NA',
#  'en-NF',
#  'en-NG',
#  'en-NL',
#  'en-NR',
#  'en-NU',
#  'en-NZ',
#  'en-PG',
#  'en-PH',
#  'en-PK',
#  'en-PN',
#  'en-PR',
#  'en-PW',
#  'en-RW',
#  'en-SB',
#  'en-SC',
#  'en-SD',
#  'en-SE',
#  'en-SG',
#  'en-SH',
#  'en-SI',
#  'en-SL',
#  'en-SS',
#  'en-SX',
#  'en-SZ',
#  'en-TC',
#  'en-TK',
#  'en-TO',
#  'en-TT',
#  'en-TV',
#  'en-TZ',
#  'en-UG',
#  'en-UM',
#  'en-US-POSIX',
#  'en-VC',
#  'en-VG',
#  'en-VI',
#  'en-VU',
#  'en-WS',
#  'en-ZA',
#  'en-ZM',
#  'en-ZW',
#  'eo',
#  'es',
#  'es-419',
#  'es-AR',
#  'es-BO',
#  'es-BR',
#  'es-BZ',
#  'es-CL',
#  'es-CO',
#  'es-CR',
#  'es-CU',
#  'es-DO',
#  'es-EA',
#  'es-EC',
#  'es-GQ',
#  'es-GT',
#  'es-HN',
#  'es-IC',
#  'es-MX',
#  'es-NI',
#  'es-PA',
#  'es-PE',
#  'es-PH',
#  'es-PR',
#  'es-PY',
#  'es-SV',
#  'es-US',
#  'es-UY',
#  'es-VE',
#  'et',
#  'eu',
#  'ewo',
#  'fa',
#  'fa-AF',
#  'ff',
#  'ff-CM',
#  'ff-GN',
#  'ff-MR',
#  'fi',
#  'fil',
#  'fo',
#  'fo-DK',
#  'fr',
#  'fr-BE',
#  'fr-BF',
#  'fr-BI',
#  'fr-BJ',
#  'fr-BL',
#  'fr-CA',
#  'fr-CD',
#  'fr-CF',
#  'fr-CG',
#  'fr-CH',
#  'fr-CI',
#  'fr-CM',
#  'fr-DJ',
#  'fr-DZ',
#  'fr-GA',
#  'fr-GF',
#  'fr-GN',
#  'fr-GP',
#  'fr-GQ',
#  'fr-HT',
#  'fr-KM',
#  'fr-LU',
#  'fr-MA',
#  'fr-MC',
#  'fr-MF',
#  'fr-MG',
#  'fr-ML',
#  'fr-MQ',
#  'fr-MR',
#  'fr-MU',
#  'fr-NC',
#  'fr-NE',
#  'fr-PF',
#  'fr-PM',
#  'fr-RE',
#  'fr-RW',
#  'fr-SC',
#  'fr-SN',
#  'fr-SY',
#  'fr-TD',
#  'fr-TG',
#  'fr-TN',
#  'fr-VU',
#  'fr-WF',
#  'fr-YT',
#  'fur',
#  'fy',
#  'ga',
#  'gd',
#  'gl',
#  'gsw',
#  'gsw-FR',
#  'gsw-LI',
#  'gu',
#  'guz',
#  'gv',
#  'ha',
#  'ha-GH',
#  'ha-NE',
#  'haw',
#  'he',
#  'hi',
#  'hr',
#  'hr-BA',
#  'hsb',
#  'hu',
#  'hy',
#  'id',
#  'ig',
#  'ii',
#  'is',
#  'it',
#  'it-CH',
#  'it-SM',
#  'it-VA',
#  'ja',
#  'jgo',
#  'jmc',
#  'ka',
#  'kab',
#  'kam',
#  'kde',
#  'kea',
#  'khq',
#  'ki',
#  'kk',
#  'kkj',
#  'kl',
#  'kln',
#  'km',
#  'kn',
#  'ko',
#  'ko-KP',
#  'kok',
#  'ks',
#  'ksb',
#  'ksf',
#  'ksh',
#  'kw',
#  'ky',
#  'lag',
#  'lb',
#  'lg',
#  'lkt',
#  'ln',
#  'ln-AO',
#  'ln-CF',
#  'ln-CG',
#  'lo',
#  'lrc',
#  'lrc-IQ',
#  'lt',
#  'lu',
#  'luo',
#  'luy',
#  'lv',
#  'mas',
#  'mas-TZ',
#  'mer',
#  'mfe',
#  'mg',
#  'mgh',
#  'mgo',
#  'mk',
#  'ml',
#  'mn',
#  'mr',
#  'ms',
#  'ms-BN',
#  'ms-SG',
#  'mt',
#  'mua',
#  'my',
#  'mzn',
#  'naq',
#  'nb',
#  'nb-SJ',
#  'nd',
#  'nds',
#  'nds-NL',
#  'ne',
#  'ne-IN',
#  'nl',
#  'nl-AW',
#  'nl-BE',
#  'nl-BQ',
#  'nl-CW',
#  'nl-SR',
#  'nl-SX',
#  'nmg',
#  'nn',
#  'nnh',
#  'nus',
#  'nyn',
#  'om',
#  'om-KE',
#  'or',
#  'os',
#  'os-RU',
#  'pa',
#  'pa-Arab',
#  'pa-Guru',
#  'pl',
#  'prg',
#  'ps',
#  'pt',
#  'pt-AO',
#  'pt-CH',
#  'pt-CV',
#  'pt-GQ',
#  'pt-GW',
#  'pt-LU',
#  'pt-MO',
#  'pt-MZ',
#  'pt-PT',
#  'pt-ST',
#  'pt-TL',
#  'qu',
#  'qu-BO',
#  'qu-EC',
#  'rm',
#  'rn',
#  'ro',
#  'ro-MD',
#  'rof',
#  'root',
#  'ru',
#  'ru-BY',
#  'ru-KG',
#  'ru-KZ',
#  'ru-MD',
#  'ru-UA',
#  'rw',
#  'rwk',
#  'sah',
#  'saq',
#  'sbp',
#  'sd',
#  'se',
#  'se-FI',
#  'se-SE',
#  'seh',
#  'ses',
#  'sg',
#  'shi',
#  'shi-Latn',
#  'shi-Tfng',
#  'si',
#  'sk',
#  'sl',
#  'smn',
#  'sn',
#  'so',
#  'so-DJ',
#  'so-ET',
#  'so-KE',
#  'sq',
#  'sq-MK',
#  'sq-XK',
#  'sr',
#  'sr-Cyrl',
#  'sr-Cyrl-BA',
#  'sr-Cyrl-ME',
#  'sr-Cyrl-XK',
#  'sr-Latn',
#  'sr-Latn-BA',
#  'sr-Latn-ME',
#  'sr-Latn-XK',
#  'sv',
#  'sv-AX',
#  'sv-FI',
#  'sw',
#  'sw-CD',
#  'sw-KE',
#  'sw-UG',
#  'ta',
#  'ta-LK',
#  'ta-MY',
#  'ta-SG',
#  'te',
#  'teo',
#  'teo-KE',
#  'tg',
#  'th',
#  'ti',
#  'ti-ER',
#  'tk',
#  'to',
#  'tr',
#  'tr-CY',
#  'tt',
#  'twq',
#  'tzm',
#  'ug',
#  'uk',
#  'ur',
#  'ur-IN',
#  'uz',
#  'uz-Arab',
#  'uz-Cyrl',
#  'uz-Latn',
#  'vai',
#  'vai-Latn',
#  'vai-Vaii',
#  'vi',
#  'vo',
#  'vun',
#  'wae',
#  'wo',
#  'xog',
#  'yav',
#  'yi',
#  'yo',
#  'yo-BJ',
#  'yue',
#  'yue-Hans',
#  'yue-Hant',
#  'zgh',
#  'zh',
#  'zh-Hans',
#  'zh-Hans-HK',
#  'zh-Hans-MO',
#  'zh-Hans-SG',
#  'zh-Hant',
#  'zh-Hant-HK',
#  'zh-Hant-MO',
#  'zu']

# %%
def local_load (loc):
    try:
        with open(loc, 'r', encoding="utf-8") as infile:
            results = json.load (infile)
    except:
        results = None
    return (results)
'''
URL_CLDR_JSON_TERRITORIES = "../main/{locale}/territories.json"
l =  locale_select[0]
results = local_load (loc  = URL_CLDR_JSON_TERRITORIES.format(locale=l))
results
'''
# Out:
# '\nURL_CLDR_JSON_TERRITORIES = "../main/{locale}/territories.json"\nl =  locale_select[0]\nresults = local_load (loc  = URL_CLDR_JSON_TERRITORIES.format(locale=l))\nresults\n'

# %%
# Partial Selected Construction
#locale_select = ['en-GB','my', 'zh-Hant'] # Can be extended in the future  'zh-Hant-HK', 'zh-Hant-MO', 'zh-Hans', 'zh-Hans-SG'

## Retrive data directly from unicode-cldr project hosted at github
print ("Retrieve data now ...")
#URL_CLDR_JSON_TERRITORIES = "https://raw.githubusercontent.com/unicode-cldr/cldr-localenames-full/master/main/{locale}/territories.json"
URL_CLDR_JSON_TERRITORIES = "../main/{locale}/territories.json"
locale_json={}
for l in locale_select:
    #results = url_request (url  = URL_CLDR_JSON_TERRITORIES.format(locale=l))
    results = local_load (loc  = URL_CLDR_JSON_TERRITORIES.format(locale=l))
    if results is not None:
        try:
            locale_json [l] = results['main'][l]['localeDisplayNames']['territories']
            print (l)
        except:
            pass
# Out:
# Retrieve data now ...
# af
# af-NA
# am
# ar
# ar-AE
# ar-BH
# ar-DJ
# ar-DZ
# ar-EG
# ar-EH
# ar-ER
# ar-IL
# ar-IQ
# ar-JO
# ar-KM
# ar-KW
# ar-LB
# ar-LY
# ar-MA
# ar-MR
# ar-OM
# ar-PS
# ar-QA
# ar-SA
# ar-SD
# ar-SO
# ar-SS
# ar-SY
# ar-TD
# ar-TN
# ar-YE
# az
# az-Latn
# be
# bg
# bn
# bn-IN
# bs
# bs-Latn
# ca
# ca-AD
# ca-ES-VALENCIA
# ca-FR
# ca-IT
# cs
# cy
# da
# da-GL
# de
# de-AT
# de-BE
# de-CH
# de-IT
# de-LI
# de-LU
# el
# el-CY
# en
# en-001
# en-150
# en-AG
# en-AI
# en-AS
# en-AT
# en-AU
# en-BB
# en-BE
# en-BI
# en-BM
# en-BS
# en-BW
# en-BZ
# en-CA
# en-CC
# en-CH
# en-CK
# en-CM
# en-CX
# en-CY
# en-DE
# en-DG
# en-DK
# en-DM
# en-ER
# en-FI
# en-FJ
# en-FK
# en-FM
# en-GB
# en-GD
# en-GG
# en-GH
# en-GI
# en-GM
# en-GU
# en-GY
# en-HK
# en-IE
# en-IL
# en-IM
# en-IN
# en-IO
# en-JE
# en-JM
# en-KE
# en-KI
# en-KN
# en-KY
# en-LC
# en-LR
# en-LS
# en-MG
# en-MH
# en-MO
# en-MP
# en-MS
# en-MT
# en-MU
# en-MW
# en-MY
# en-NA
# en-NF
# en-NG
# en-NL
# en-NR
# en-NU
# en-NZ
# en-PG
# en-PH
# en-PK
# en-PN
# en-PR
# en-PW
# en-RW
# en-SB
# en-SC
# en-SD
# en-SE
# en-SG
# en-SH
# en-SI
# en-SL
# en-SS
# en-SX
# en-SZ
# en-TC
# en-TK
# en-TO
# en-TT
# en-TV
# en-TZ
# en-UG
# en-UM
# en-US-POSIX
# en-VC
# en-VG
# en-VI
# en-VU
# en-WS
# en-ZA
# en-ZM
# en-ZW
# es
# es-419
# es-AR
# es-BO
# es-BR
# es-BZ
# es-CL
# es-CO
# es-CR
# es-CU
# es-DO
# es-EA
# es-EC
# es-GQ
# es-GT
# es-HN
# es-IC
# es-MX
# es-NI
# es-PA
# es-PE
# es-PH
# es-PR
# es-PY
# es-SV
# es-US
# es-UY
# es-VE
# et
# eu
# fa
# fa-AF
# fi
# fil
# fo
# fo-DK
# fr
# fr-BE
# fr-BF
# fr-BI
# fr-BJ
# fr-BL
# fr-CA
# fr-CD
# fr-CF
# fr-CG
# fr-CH
# fr-CI
# fr-CM
# fr-DJ
# fr-DZ
# fr-GA
# fr-GF
# fr-GN
# fr-GP
# fr-GQ
# fr-HT
# fr-KM
# fr-LU
# fr-MA
# fr-MC
# fr-MF
# fr-MG
# fr-ML
# fr-MQ
# fr-MR
# fr-MU
# fr-NC
# fr-NE
# fr-PF
# fr-PM
# fr-RE
# fr-RW
# fr-SC
# fr-SN
# fr-SY
# fr-TD
# fr-TG
# fr-TN
# fr-VU
# fr-WF
# fr-YT
# ga
# gl
# gu
# he
# hi
# hr
# hr-BA
# hu
# hy
# id
# is
# it
# it-CH
# it-SM
# it-VA
# ja
# ka
# kk
# km
# kn
# ko
# ko-KP
# ky
# lo
# lt
# lv
# mk
# ml
# mn
# mr
# ms
# ms-BN
# ms-SG
# my
# nb
# nb-SJ
# ne
# ne-IN
# nl
# nl-AW
# nl-BE
# nl-BQ
# nl-CW
# nl-SR
# nl-SX
# pa
# pa-Guru
# pl
# pt
# pt-AO
# pt-CH
# pt-CV
# pt-GQ
# pt-GW
# pt-LU
# pt-MO
# pt-MZ
# pt-PT
# pt-ST
# pt-TL
# ro
# ro-MD
# root
# ru
# ru-BY
# ru-KG
# ru-KZ
# ru-MD
# ru-UA
# si
# sk
# sl
# sq
# sq-MK
# sq-XK
# sr
# sr-Cyrl
# sr-Cyrl-BA
# sr-Cyrl-ME
# sr-Cyrl-XK
# sr-Latn
# sr-Latn-BA
# sr-Latn-ME
# sr-Latn-XK
# sv
# sv-AX
# sv-FI
# sw
# sw-CD
# sw-KE
# sw-UG
# ta
# ta-LK
# ta-MY
# ta-SG
# te
# th
# to
# tr
# tr-CY
# uk
# ur
# ur-IN
# uz
# uz-Latn
# vi
# yue
# yue-Hant
# zh
# zh-Hans
# zh-Hans-HK
# zh-Hans-MO
# zh-Hans-SG
# zh-Hant
# zh-Hant-HK
# zh-Hant-MO
# zu

# %%
results['main'][l]['localeDisplayNames']['territories']
# Out:
# {'001': 'umhlaba',
#  '002': 'i-Africa',
#  '003': 'i-North America',
#  '005': 'i-South America',
#  '009': 'i-Oceania',
#  '011': 'i-Western Africa',
#  '013': 'i-Central America',
#  '014': 'i-Eastern Africa',
#  '015': 'i-Northern Africa',
#  '017': 'i-Middle Africa',
#  '018': 'i-Southern Africa',
#  '019': 'i-Americas',
#  '021': 'i-Northern America',
#  '029': 'i-Caribbean',
#  '030': 'i-Eastern Asia',
#  '034': 'i-Southern Asia',
#  '035': 'i-South-Eastern Asia',
#  '039': 'i-Southern Europe',
#  '053': 'i-Australasia',
#  '054': 'i-Melanesia',
#  '057': 'i-Micronesian Region',
#  '061': 'i-Polynesia',
#  '142': 'i-Asia',
#  '143': 'i-Central Asia',
#  '145': 'i-Western Asia',
#  '150': 'i-Europe',
#  '151': 'i-Eastern Europe',
#  '154': 'i-Northern Europe',
#  '155': 'i-Western Europe',
#  '202': 'Sub-Saharan Africa',
#  '419': 'i-Latin America',
#  'AC': 'i-Ascension Island',
#  'AD': 'i-Andorra',
#  'AE': 'i-United Arab Emirates',
#  'AF': 'i-Afghanistan',
#  'AG': 'i-Antigua ne-Barbuda',
#  'AI': 'i-Anguilla',
#  'AL': 'i-Albania',
#  'AM': 'i-Armenia',
#  'AO': 'i-Angola',
#  'AQ': 'i-Antarctica',
#  'AR': 'i-Argentina',
#  'AS': 'i-American Samoa',
#  'AT': 'i-Austria',
#  'AU': 'i-Australia',
#  'AW': 'i-Aruba',
#  'AX': 'i-Åland Islands',
#  'AZ': 'i-Azerbaijan',
#  'BA': 'i-Bosnia ne-Herzegovina',
#  'BB': 'i-Barbados',
#  'BD': 'i-Bangladesh',
#  'BE': 'i-Belgium',
#  'BF': 'i-Burkina Faso',
#  'BG': 'i-Bulgaria',
#  'BH': 'i-Bahrain',
#  'BI': 'i-Burundi',
#  'BJ': 'i-Benin',
#  'BL': 'i-Saint Barthélemy',
#  'BM': 'i-Bermuda',
#  'BN': 'i-Brunei',
#  'BO': 'i-Bolivia',
#  'BQ': 'i-Caribbean Netherlands',
#  'BR': 'i-Brazil',
#  'BS': 'i-Bahamas',
#  'BT': 'i-Bhutan',
#  'BV': 'i-Bouvet Island',
#  'BW': 'iBotswana',
#  'BY': 'i-Belarus',
#  'BZ': 'i-Belize',
#  'CA': 'i-Canada',
#  'CC': 'i-Cocos (Keeling) Islands',
#  'CD': 'i-Congo - Kinshasa',
#  'CD-alt-variant': 'i-Congo (DRC)',
#  'CF': 'i-Central African Republic',
#  'CG': 'i-Congo - Brazzaville',
#  'CG-alt-variant': 'i-Congo (Republic)',
#  'CH': 'i-Switzerland',
#  'CI': 'i-Côte d’Ivoire',
#  'CI-alt-variant': 'i-Ivory Coast',
#  'CK': 'i-Cook Islands',
#  'CL': 'i-Chile',
#  'CM': 'i-Cameroon',
#  'CN': 'i-China',
#  'CO': 'i-Colombia',
#  'CP': 'i-Clipperton Island',
#  'CR': 'i-Costa Rica',
#  'CU': 'i-Cuba',
#  'CV': 'i-Cape Verde',
#  'CW': 'i-Curaçao',
#  'CX': 'i-Christmas Island',
#  'CY': 'i-Cyprus',
#  'CZ': 'i-Czechia',
#  'CZ-alt-variant': 'i-Czech Republic',
#  'DE': 'i-Germany',
#  'DG': 'i-Diego Garcia',
#  'DJ': 'i-Djibouti',
#  'DK': 'i-Denmark',
#  'DM': 'i-Dominica',
#  'DO': 'i-Dominican Republic',
#  'DZ': 'i-Algeria',
#  'EA': 'i-Cueta ne-Melilla',
#  'EC': 'i-Ecuador',
#  'EE': 'i-Estonia',
#  'EG': 'i-Egypt',
#  'EH': 'i-Western Sahara',
#  'ER': 'i-Eritrea',
#  'ES': 'i-Spain',
#  'ET': 'i-Ethiopia',
#  'EU': 'i-European Union',
#  'EZ': 'EZ',
#  'FI': 'i-Finland',
#  'FJ': 'i-Fiji',
#  'FK': 'i-Falkland Islands',
#  'FK-alt-variant': 'i-Falkland Islands (Islas Malvinas)',
#  'FM': 'i-Micronesia',
#  'FO': 'i-Faroe Islands',
#  'FR': 'i-France',
#  'GA': 'i-Gabon',
#  'GB': 'i-United Kingdom',
#  'GB-alt-short': 'i-U.K.',
#  'GD': 'i-Grenada',
#  'GE': 'i-Georgia',
#  'GF': 'i-French Guiana',
#  'GG': 'i-Guernsey',
#  'GH': 'i-Ghana',
#  'GI': 'i-Gibraltar',
#  'GL': 'i-Greenland',
#  'GM': 'i-Gambia',
#  'GN': 'i-Guinea',
#  'GP': 'i-Guadeloupe',
#  'GQ': 'i-Equatorial Guinea',
#  'GR': 'i-Greece',
#  'GS': 'i-South Georgia ne-South Sandwich Islands',
#  'GT': 'i-Guatemala',
#  'GU': 'i-Guam',
#  'GW': 'i-Guinea-Bissau',
#  'GY': 'i-Guyana',
#  'HK': 'i-Hong Kong SAR China',
#  'HK-alt-short': 'i-Hong Kong',
#  'HM': 'i-Heard Island ne-McDonald Islands',
#  'HN': 'i-Honduras',
#  'HR': 'i-Croatia',
#  'HT': 'i-Haiti',
#  'HU': 'i-Hungary',
#  'IC': 'i-Canary Islands',
#  'ID': 'i-Indonesia',
#  'IE': 'i-Ireland',
#  'IL': 'kwa-Israel',
#  'IM': 'i-Isle of Man',
#  'IN': 'i-India',
#  'IO': 'i-British Indian Ocean Territory',
#  'IQ': 'i-Iraq',
#  'IR': 'i-Iran',
#  'IS': 'i-Iceland',
#  'IT': 'i-Italy',
#  'JE': 'i-Jersey',
#  'JM': 'i-Jamaica',
#  'JO': 'i-Jordan',
#  'JP': 'i-Japan',
#  'KE': 'i-Kenya',
#  'KG': 'i-Kyrgyzstan',
#  'KH': 'i-Cambodia',
#  'KI': 'i-Kiribati',
#  'KM': 'i-Comoros',
#  'KN': 'i-Saint Kitts ne-Nevis',
#  'KP': 'i-North Korea',
#  'KR': 'i-South Korea',
#  'KW': 'i-Kuwait',
#  'KY': 'i-Cayman Islands',
#  'KZ': 'i-Kazakhstan',
#  'LA': 'i-Laos',
#  'LB': 'i-Lebanon',
#  'LC': 'i-Saint Lucia',
#  'LI': 'i-Liechtenstein',
#  'LK': 'i-Sri Lanka',
#  'LR': 'i-Liberia',
#  'LS': 'iLesotho',
#  'LT': 'i-Lithuania',
#  'LU': 'i-Luxembourg',
#  'LV': 'i-Latvia',
#  'LY': 'i-Libya',
#  'MA': 'i-Morocco',
#  'MC': 'i-Monaco',
#  'MD': 'i-Moldova',
#  'ME': 'i-Montenegro',
#  'MF': 'i-Saint Martin',
#  'MG': 'i-Madagascar',
#  'MH': 'i-Marshall Islands',
#  'MK': 'i-Macedonia',
#  'MK-alt-variant': 'i-Macedonia (FYROM)',
#  'ML': 'iMali',
#  'MM': 'i-Myanmar (Burma)',
#  'MN': 'i-Mongolia',
#  'MO': 'i-Macau SAR China',
#  'MO-alt-short': 'i-Macau',
#  'MP': 'i-Northern Mariana Islands',
#  'MQ': 'i-Martinique',
#  'MR': 'i-Mauritania',
#  'MS': 'i-Montserrat',
#  'MT': 'i-Malta',
#  'MU': 'i-Mauritius',
#  'MV': 'i-Maldives',
#  'MW': 'iMalawi',
#  'MX': 'i-Mexico',
#  'MY': 'i-Malaysia',
#  'MZ': 'i-Mozambique',
#  'NA': 'i-Namibia',
#  'NC': 'i-New Caledonia',
#  'NE': 'i-Niger',
#  'NF': 'i-Norfolk Island',
#  'NG': 'i-Nigeria',
#  'NI': 'i-Nicaragua',
#  'NL': 'i-Netherlands',
#  'NO': 'i-Norway',
#  'NP': 'i-Nepal',
#  'NR': 'i-Nauru',
#  'NU': 'i-Niue',
#  'NZ': 'i-New Zealand',
#  'OM': 'i-Oman',
#  'PA': 'i-Panama',
#  'PE': 'i-Peru',
#  'PF': 'i-French Polynesia',
#  'PG': 'i-Papua New Guinea',
#  'PH': 'i-Philippines',
#  'PK': 'i-Pakistan',
#  'PL': 'i-Poland',
#  'PM': 'i-Saint Pierre kanye ne-Miquelon',
#  'PN': 'i-Pitcairn Islands',
#  'PR': 'i-Puerto Rico',
#  'PS': 'i-Palestinian Territories',
#  'PS-alt-short': 'i-Palestine',
#  'PT': 'i-Portugal',
#  'PW': 'i-Palau',
#  'PY': 'i-Paraguay',
#  'QA': 'i-Qatar',
#  'QO': 'i-Outlying Oceania',
#  'RE': 'i-Réunion',
#  'RO': 'i-Romania',
#  'RS': 'i-Serbia',
#  'RU': 'i-Russia',
#  'RW': 'i-Rwanda',
#  'SA': 'i-Saudi Arabia',
#  'SB': 'i-Solomon Islands',
#  'SC': 'i-Seychelles',
#  'SD': 'i-Sudan',
#  'SE': 'i-Sweden',
#  'SG': 'i-Singapore',
#  'SH': 'i-St. Helena',
#  'SI': 'i-Slovenia',
#  'SJ': 'i-Svalbard ne-Jan Mayen',
#  'SK': 'i-Slovakia',
#  'SL': 'i-Sierra Leone',
#  'SM': 'i-San Marino',
#  'SN': 'i-Senegal',
#  'SO': 'i-Somalia',
#  'SR': 'i-Suriname',
#  'SS': 'i-South Sudan',
#  'ST': 'i-São Tomé kanye ne-Príncipe',
#  'SV': 'i-El Salvador',
#  'SX': 'i-Sint Maarten',
#  'SY': 'i-Syria',
#  'SZ': 'i-Swaziland',
#  'TA': 'i-Tristan da Cunha',
#  'TC': 'i-Turks ne-Caicos Islands',
#  'TD': 'i-Chad',
#  'TF': 'i-French Southern Territories',
#  'TG': 'i-Togo',
#  'TH': 'i-Thailand',
#  'TJ': 'i-Tajikistan',
#  'TK': 'i-Tokelau',
#  'TL': 'i-Timor-Leste',
#  'TL-alt-variant': 'i-East Timor',
#  'TM': 'i-Turkmenistan',
#  'TN': 'i-Tunisia',
#  'TO': 'i-Tonga',
#  'TR': 'i-Turkey',
#  'TT': 'i-Trinidad ne-Tobago',
#  'TV': 'i-Tuvalu',
#  'TW': 'i-Taiwan',
#  'TZ': 'i-Tanzania',
#  'UA': 'i-Ukraine',
#  'UG': 'i-Uganda',
#  'UM': 'i-U.S. Minor Outlying Islands',
#  'UN': 'I-United Nations',
#  'UN-alt-short': 'ifulegi',
#  'US': 'i-United States',
#  'US-alt-short': 'i-U.S',
#  'UY': 'i-Uruguay',
#  'UZ': 'i-Uzbekistan',
#  'VA': 'i-Vatican City',
#  'VC': 'i-Saint Vincent ne-Grenadines',
#  'VE': 'i-Venezuela',
#  'VG': 'i-British Virgin Islands',
#  'VI': 'i-U.S. Virgin Islands',
#  'VN': 'i-Vietnam',
#  'VU': 'i-Vanuatu',
#  'WF': 'i-Wallis ne-Futuna',
#  'WS': 'i-Samoa',
#  'XK': 'i-Kosovo',
#  'YE': 'i-Yemen',
#  'YT': 'i-Mayotte',
#  'ZA': 'iNingizimu Afrika',
#  'ZM': 'i-Zambia',
#  'ZW': 'iZimbabwe',
#  'ZZ': 'iSifunda esingaziwa'}

# %%
## Preprocessing and Generating lists
print ("Preprocessing data now ...")
ITEM_NAME_CODE = "{name}[{code}]"
ITEM_CODE_NAME = "{code}:{name}"

outputlist_territories={}
for key, value in locale_json.items():
    ### Remove UN regional codes (three digits)  
    value_new = {k: v for k, v in value.items() if k.isdigit() is not True}

    ### Generate items for different group of lists
    n_c_full_data=[]
    n_c_data=[]
    c_n_data=[]
    #r_n=dict()  #region--names

    c_n=dict()
    for k, v in value_new.items():
        
        ## n_c_full_data are complete list
        n_c_full_data.append(ITEM_NAME_CODE.format(name=v, code=k))    

        ### Remove -alt-variant and -alt-short
        if len(k)>2:
            if "-alt-variant" in k:
                #print (">NOT using:{}".format([k,v]))
                pass
            if "-alt-short" in k:  ## Using -alt-short if exists
                k=k.replace("-alt-short", "")
                print (">    using:{}".format([k,v]))
                c_n.update({k:v})
            #if len(k)==3 and k.isdigit():
            #    r_n.update({k:v})  ## UN region codes
            
        else:
            if k not in c_n.keys():
                c_n.update({k:v})
            else:
                print (">NOT using:{}".format([k,v]))

    for k,v in c_n.items():
        n_c_data.append(ITEM_NAME_CODE.format(name=v, code=k))
        c_n_data.append(ITEM_CODE_NAME.format(name=v, code=k))
   
    ### Sort by IBM's ICU library, which uses the full Unicode Collation Algorithm
    print (key)
    collator = icu.Collator.createInstance(icu.Locale('{lc}.UTF-8'.format(lc=key)))
    n_c_data = sorted(n_c_data, key=collator.getSortKey )
    c_n_data = sorted(c_n_data, key=collator.getSortKey )

    outputlist_territories [key]  = n_c_data + c_n_data
# Out:
# Preprocessing data now ...
# >    using:['GB', 'VK']
# >    using:['HK', 'Hongkong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'VN']
# >    using:['US', 'VSA']
# af
# >    using:['GB', 'VK']
# >    using:['HK', 'Hongkong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'VN']
# >    using:['US', 'VSA']
# af-NA
# >    using:['GB', 'ዩናይትድ ኪንግደም']
# >    using:['HK', 'ሆንግ ኮንግ']
# >    using:['MO', 'ማካኡ']
# >    using:['PS', 'ፍልስጥኤም']
# >    using:['UN', 'የተመ']
# >    using:['US', 'ዩ ኤስ']
# am
# >    using:['GB', 'المملكة المتحدة']
# >    using:['HK', 'هونغ كونغ']
# >    using:['MO', 'مكاو']
# >    using:['PS', 'فلسطين']
# >    using:['UN', 'الأمم المتحدة']
# >    using:['US', 'الولايات المتحدة']
# ar
# >    using:['GB', 'المملكة المتحدة']
# >    using:['HK', 'هونغ كونغ']
# >    using:['MO', 'مكاو']
# >    using:['PS', 'فلسطين']
# >    using:['UN', 'الأمم المتحدة']
# >    using:['US', 'الولايات المتحدة']
# ar-AE
# >    using:['GB', 'المملكة المتحدة']
# >    using:['HK', 'هونغ كونغ']
# >    using:['MO', 'مكاو']
# >    using:['PS', 'فلسطين']
# >    using:['UN', 'الأمم المتحدة']
# >    using:['US', 'الولايات المتحدة']
# ar-BH
# >    using:['GB', 'المملكة المتحدة']
# >    using:['HK', 'هونغ كونغ']
# >    using:['MO', 'مكاو']
# >    using:['PS', 'فلسطين']
# >    using:['UN', 'الأمم المتحدة']
# >    using:['US', 'الولايات المتحدة']
# ar-DJ
# >    using:['GB', 'المملكة المتحدة']
# >    using:['HK', 'هونغ كونغ']
# >    using:['MO', 'مكاو']
# >    using:['PS', 'فلسطين']
# >    using:['UN', 'الأمم المتحدة']
# >    using:['US', 'الولايات المتحدة']
# ar-DZ
# >    using:['GB', 'المملكة المتحدة']
# >    using:['HK', 'هونغ كونغ']
# >    using:['MO', 'مكاو']
# >    using:['PS', 'فلسطين']
# >    using:['UN', 'الأمم المتحدة']
# >    using:['US', 'الولايات المتحدة']
# ar-EG
# >    using:['GB', 'المملكة المتحدة']
# >    using:['HK', 'هونغ كونغ']
# >    using:['MO', 'مكاو']
# >    using:['PS', 'فلسطين']
# >    using:['UN', 'الأمم المتحدة']
# >    using:['US', 'الولايات المتحدة']
# ar-EH
# >    using:['GB', 'المملكة المتحدة']
# >    using:['HK', 'هونغ كونغ']
# >    using:['MO', 'مكاو']
# >    using:['PS', 'فلسطين']
# >    using:['UN', 'الأمم المتحدة']
# >    using:['US', 'الولايات المتحدة']
# ar-ER
# >    using:['GB', 'المملكة المتحدة']
# >    using:['HK', 'هونغ كونغ']
# >    using:['MO', 'مكاو']
# >    using:['PS', 'فلسطين']
# >    using:['UN', 'الأمم المتحدة']
# >    using:['US', 'الولايات المتحدة']
# ar-IL
# >    using:['GB', 'المملكة المتحدة']
# >    using:['HK', 'هونغ كونغ']
# >    using:['MO', 'مكاو']
# >    using:['PS', 'فلسطين']
# >    using:['UN', 'الأمم المتحدة']
# >    using:['US', 'الولايات المتحدة']
# ar-IQ
# >    using:['GB', 'المملكة المتحدة']
# >    using:['HK', 'هونغ كونغ']
# >    using:['MO', 'مكاو']
# >    using:['PS', 'فلسطين']
# >    using:['UN', 'الأمم المتحدة']
# >    using:['US', 'الولايات المتحدة']
# ar-JO
# >    using:['GB', 'المملكة المتحدة']
# >    using:['HK', 'هونغ كونغ']
# >    using:['MO', 'مكاو']
# >    using:['PS', 'فلسطين']
# >    using:['UN', 'الأمم المتحدة']
# >    using:['US', 'الولايات المتحدة']
# ar-KM
# >    using:['GB', 'المملكة المتحدة']
# >    using:['HK', 'هونغ كونغ']
# >    using:['MO', 'مكاو']
# >    using:['PS', 'فلسطين']
# >    using:['UN', 'الأمم المتحدة']
# >    using:['US', 'الولايات المتحدة']
# ar-KW
# >    using:['GB', 'المملكة المتحدة']
# >    using:['HK', 'هونغ كونغ']
# >    using:['MO', 'مكاو']
# >    using:['PS', 'فلسطين']
# >    using:['UN', 'الأمم المتحدة']
# >    using:['US', 'الولايات المتحدة']
# ar-LB
# >    using:['GB', 'المملكة المتحدة']
# >    using:['HK', 'هونغ كونغ']
# >    using:['MO', 'مكاو']
# >    using:['PS', 'فلسطين']
# >    using:['UN', 'الأمم المتحدة']
# >    using:['US', 'الولايات المتحدة']
# ar-LY
# >    using:['GB', 'المملكة المتحدة']
# >    using:['HK', 'هونغ كونغ']
# >    using:['MO', 'مكاو']
# >    using:['PS', 'فلسطين']
# >    using:['UN', 'الأمم المتحدة']
# >    using:['US', 'الولايات المتحدة']
# ar-MA
# >    using:['GB', 'المملكة المتحدة']
# >    using:['HK', 'هونغ كونغ']
# >    using:['MO', 'مكاو']
# >    using:['PS', 'فلسطين']
# >    using:['UN', 'الأمم المتحدة']
# >    using:['US', 'الولايات المتحدة']
# ar-MR
# >    using:['GB', 'المملكة المتحدة']
# >    using:['HK', 'هونغ كونغ']
# >    using:['MO', 'مكاو']
# >    using:['PS', 'فلسطين']
# >    using:['UN', 'الأمم المتحدة']
# >    using:['US', 'الولايات المتحدة']
# ar-OM
# >    using:['GB', 'المملكة المتحدة']
# >    using:['HK', 'هونغ كونغ']
# >    using:['MO', 'مكاو']
# >    using:['PS', 'فلسطين']
# >    using:['UN', 'الأمم المتحدة']
# >    using:['US', 'الولايات المتحدة']
# ar-PS
# >    using:['GB', 'المملكة المتحدة']
# >    using:['HK', 'هونغ كونغ']
# >    using:['MO', 'مكاو']
# >    using:['PS', 'فلسطين']
# >    using:['UN', 'الأمم المتحدة']
# >    using:['US', 'الولايات المتحدة']
# ar-QA
# >    using:['GB', 'المملكة المتحدة']
# >    using:['HK', 'هونغ كونغ']
# >    using:['MO', 'ماكاو']
# >    using:['PS', 'فلسطين']
# >    using:['UN', 'الأمم المتحدة']
# >    using:['US', 'الولايات المتحدة']
# ar-SA
# >    using:['GB', 'المملكة المتحدة']
# >    using:['HK', 'هونغ كونغ']
# >    using:['MO', 'مكاو']
# >    using:['PS', 'فلسطين']
# >    using:['UN', 'الأمم المتحدة']
# >    using:['US', 'الولايات المتحدة']
# ar-SD
# >    using:['GB', 'المملكة المتحدة']
# >    using:['HK', 'هونغ كونغ']
# >    using:['MO', 'مكاو']
# >    using:['PS', 'فلسطين']
# >    using:['UN', 'الأمم المتحدة']
# >    using:['US', 'الولايات المتحدة']
# ar-SO
# >    using:['GB', 'المملكة المتحدة']
# >    using:['HK', 'هونغ كونغ']
# >    using:['MO', 'مكاو']
# >    using:['PS', 'فلسطين']
# >    using:['UN', 'الأمم المتحدة']
# >    using:['US', 'الولايات المتحدة']
# ar-SS
# >    using:['GB', 'المملكة المتحدة']
# >    using:['HK', 'هونغ كونغ']
# >    using:['MO', 'مكاو']
# >    using:['PS', 'فلسطين']
# >    using:['UN', 'الأمم المتحدة']
# >    using:['US', 'الولايات المتحدة']
# ar-SY
# >    using:['GB', 'المملكة المتحدة']
# >    using:['HK', 'هونغ كونغ']
# >    using:['MO', 'مكاو']
# >    using:['PS', 'فلسطين']
# >    using:['UN', 'الأمم المتحدة']
# >    using:['US', 'الولايات المتحدة']
# ar-TD
# >    using:['GB', 'المملكة المتحدة']
# >    using:['HK', 'هونغ كونغ']
# >    using:['MO', 'مكاو']
# >    using:['PS', 'فلسطين']
# >    using:['UN', 'الأمم المتحدة']
# >    using:['US', 'الولايات المتحدة']
# ar-TN
# >    using:['GB', 'المملكة المتحدة']
# >    using:['HK', 'هونغ كونغ']
# >    using:['MO', 'مكاو']
# >    using:['PS', 'فلسطين']
# >    using:['UN', 'الأمم المتحدة']
# >    using:['US', 'الولايات المتحدة']
# ar-YE
# >    using:['GB', 'BK']
# >    using:['HK', 'Honq Konq']
# >    using:['MO', 'Makao']
# >    using:['PS', 'Fələstin']
# >    using:['UN', 'BMT']
# >    using:['US', 'ABŞ']
# az
# >    using:['GB', 'BK']
# >    using:['HK', 'Honq Konq']
# >    using:['MO', 'Makao']
# >    using:['PS', 'Fələstin']
# >    using:['UN', 'BMT']
# >    using:['US', 'ABŞ']
# az-Latn
# >    using:['GB', 'Вялікабрытанія']
# >    using:['HK', 'Ганконг']
# >    using:['MO', 'Макаа']
# >    using:['PS', 'Палесціна']
# >    using:['US', 'ЗША']
# be
# >    using:['GB', 'Обединеното кралство']
# >    using:['HK', 'Хонконг']
# >    using:['MO', 'Макао']
# >    using:['PS', 'Палестина']
# >    using:['US', 'САЩ']
# bg
# >    using:['GB', 'ইউ কে']
# >    using:['HK', 'হংকং']
# >    using:['MO', 'ম্যাকাও']
# >    using:['PS', 'ফিলিস্তিন']
# >    using:['UN', 'ইউএন']
# >    using:['US', 'ইউ এস']
# bn
# >    using:['GB', 'ইউ কে']
# >    using:['HK', 'হংকং']
# >    using:['MO', 'ম্যাকাও']
# >    using:['PS', 'ফিলিস্তিন']
# >    using:['UN', 'ইউএন']
# >    using:['US', 'ইউ এস']
# bn-IN
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Makao']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'UN']
# >    using:['US', 'SAD']
# bs
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Makao']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'UN']
# >    using:['US', 'SAD']
# bs-Latn
# >    using:['GB', 'RU']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'ONU']
# >    using:['US', 'EUA']
# ca
# >    using:['GB', 'RU']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'ONU']
# >    using:['US', 'EUA']
# ca-AD
# >    using:['GB', 'RU']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'ONU']
# >    using:['US', 'EUA']
# ca-ES-VALENCIA
# >    using:['GB', 'RU']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'ONU']
# >    using:['US', 'EUA']
# ca-FR
# >    using:['GB', 'RU']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'ONU']
# >    using:['US', 'EUA']
# ca-IT
# >    using:['GB', 'GB']
# >    using:['HK', 'Hongkong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'OSN']
# >    using:['US', 'USA']
# cs
# >    using:['GB', 'DU']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palesteina']
# >    using:['UN', 'UN']
# >    using:['US', 'UDA']
# cy
# >    using:['GB', 'UK']
# >    using:['HK', 'Hongkong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palæstina']
# >    using:['UN', 'FN']
# >    using:['US', 'USA']
# da
# >    using:['GB', 'UK']
# >    using:['HK', 'Hongkong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palæstina']
# >    using:['UN', 'FN']
# >    using:['US', 'USA']
# da-GL
# >    using:['GB', 'GB']
# >    using:['HK', 'Hongkong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palästina']
# >    using:['UN', 'UN']
# >    using:['US', 'USA']
# de
# >    using:['GB', 'GB']
# >    using:['HK', 'Hongkong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palästina']
# >    using:['UN', 'UN']
# >    using:['US', 'USA']
# de-AT
# >    using:['GB', 'GB']
# >    using:['HK', 'Hongkong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palästina']
# >    using:['UN', 'UN']
# >    using:['US', 'USA']
# de-BE
# >    using:['GB', 'GB']
# >    using:['HK', 'Hongkong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palästina']
# >    using:['UN', 'UN']
# >    using:['US', 'USA']
# de-CH
# >    using:['GB', 'GB']
# >    using:['HK', 'Hongkong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palästina']
# >    using:['UN', 'UN']
# >    using:['US', 'USA']
# de-IT
# >    using:['GB', 'GB']
# >    using:['HK', 'Hongkong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palästina']
# >    using:['UN', 'UN']
# >    using:['US', 'USA']
# de-LI
# >    using:['GB', 'GB']
# >    using:['HK', 'Hongkong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palästina']
# >    using:['UN', 'UN']
# >    using:['US', 'USA']
# de-LU
# >    using:['GB', 'ΗΒ']
# >    using:['HK', 'Χονγκ Κονγκ']
# >    using:['MO', 'Μακάο']
# >    using:['PS', 'Παλαιστίνη']
# >    using:['UN', 'ΟΗΕ']
# >    using:['US', 'ΗΠΑ']
# el
# >    using:['GB', 'ΗΒ']
# >    using:['HK', 'Χονγκ Κονγκ']
# >    using:['MO', 'Μακάο']
# >    using:['PS', 'Παλαιστίνη']
# >    using:['UN', 'ΟΗΕ']
# >    using:['US', 'ΗΠΑ']
# el-CY
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-001
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-150
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-AG
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-AI
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-AS
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-AT
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-AU
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-BB
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-BE
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-BI
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-BM
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-BS
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-BW
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-BZ
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-CA
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-CC
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-CH
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-CK
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-CM
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-CX
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-CY
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-DE
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-DG
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-DK
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-DM
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-ER
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-FI
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-FJ
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-FK
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-FM
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-GB
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-GD
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-GG
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-GH
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-GI
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-GM
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-GU
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-GY
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-HK
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-IE
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-IL
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-IM
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-IN
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-IO
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-JE
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-JM
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-KE
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-KI
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-KN
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-KY
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-LC
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-LR
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-LS
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-MG
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-MH
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-MO
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-MP
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-MS
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-MT
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-MU
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-MW
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-MY
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-NA
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-NF
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-NG
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-NL
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-NR
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-NU
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-NZ
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-PG
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-PH
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-PK
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-PN
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-PR
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-PW
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-RW
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-SB
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-SC
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-SD
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-SE
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-SG
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-SH
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-SI
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-SL
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-SS
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-SX
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-SZ
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-TC
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-TK
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-TO
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-TT
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-TV
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-TZ
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-UG
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-UM
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-US-POSIX
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-VC
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-VG
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-VI
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-VU
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-WS
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-ZA
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-ZM
# >    using:['BA', 'Bosnia']
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MM', 'Myanmar']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'US']
# en-ZW
# >    using:['GB', 'RU']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['US', 'EE. UU.']
# es
# >    using:['GB', 'R. U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['US', 'EE. UU.']
# es-419
# >    using:['GB', 'RU']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['US', 'EE. UU.']
# es-AR
# >    using:['GB', 'RU']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['US', 'EE. UU.']
# es-BO
# >    using:['GB', 'R. U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['US', 'EE. UU.']
# es-BR
# >    using:['GB', 'R. U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['US', 'EE. UU.']
# es-BZ
# >    using:['GB', 'RU']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['US', 'EE. UU.']
# es-CL
# >    using:['GB', 'RU']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['US', 'EE. UU.']
# es-CO
# >    using:['GB', 'RU']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['US', 'EE. UU.']
# es-CR
# >    using:['GB', 'R. U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['US', 'EE. UU.']
# es-CU
# >    using:['GB', 'RU']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['US', 'EE. UU.']
# es-DO
# >    using:['GB', 'RU']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['US', 'EE. UU.']
# es-EA
# >    using:['GB', 'RU']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['US', 'EE. UU.']
# es-EC
# >    using:['GB', 'RU']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['US', 'EE. UU.']
# es-GQ
# >    using:['GB', 'RU']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['US', 'EE. UU.']
# es-GT
# >    using:['GB', 'RU']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['US', 'EE. UU.']
# es-HN
# >    using:['GB', 'RU']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['US', 'EE. UU.']
# es-IC
# >    using:['GB', 'RU']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['US', 'EE. UU.']
# es-MX
# >    using:['GB', 'RU']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['US', 'EE. UU.']
# es-NI
# >    using:['GB', 'RU']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['US', 'EE. UU.']
# es-PA
# >    using:['GB', 'RU']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['US', 'EE. UU.']
# es-PE
# >    using:['GB', 'RU']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['US', 'EE. UU.']
# es-PH
# >    using:['GB', 'R. U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['US', 'EE. UU.']
# es-PR
# >    using:['GB', 'RU']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['US', 'EE. UU.']
# es-PY
# >    using:['GB', 'R. U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['US', 'EE. UU.']
# es-SV
# >    using:['GB', 'RU']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['US', 'EE. UU.']
# es-US
# >    using:['GB', 'R. U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['US', 'EE. UU.']
# es-UY
# >    using:['GB', 'RU']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['US', 'EE. UU.']
# es-VE
# >    using:['GB', 'ÜK']
# >    using:['HK', 'Hongkong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestiina']
# >    using:['UN', 'ÜRO']
# >    using:['US', 'USA']
# et
# >    using:['GB', 'EB']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestina']
# >    using:['US', 'AEB']
# eu
# >    using:['GB', 'بریتانیا']
# >    using:['HK', 'هنگ\u200cکنگ']
# >    using:['MO', 'ماکائو']
# >    using:['PS', 'فلسطین']
# >    using:['SA', 'عربستان']
# >    using:['UN', 'سازمان ملل']
# >    using:['US', 'ایالات متحده']
# fa
# >    using:['GB', 'بریتانیا']
# >    using:['HK', 'هنگ\u200cکنگ']
# >    using:['MO', 'ماکائو']
# >    using:['PS', 'فلسطین']
# >    using:['SA', 'عربستان']
# >    using:['UN', 'سازمان ملل']
# >    using:['US', 'ایالات متحده']
# fa-AF
# >    using:['GB', 'Britannia']
# >    using:['HK', 'Hongkong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestiina']
# >    using:['UN', 'YK']
# >    using:['US', 'USA']
# fi
# >    using:['GB', 'U.K.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'UN']
# >    using:['US', 'U.S.']
# fil
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Makao']
# >    using:['PS', 'Palestina']
# >    using:['US', 'USA']
# fo
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Makao']
# >    using:['PS', 'Palestina']
# >    using:['US', 'USA']
# fo-DK
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-BE
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-BF
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-BI
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-BJ
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-BL
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-CA
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-CD
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-CF
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-CG
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-CH
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-CI
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-CM
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-DJ
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-DZ
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-GA
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-GF
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-GN
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-GP
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-GQ
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-HT
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-KM
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-LU
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-MA
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-MC
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-MF
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-MG
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-ML
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-MQ
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-MR
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-MU
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-NC
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-NE
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-PF
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-PM
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-RE
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-RW
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-SC
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-SN
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-SY
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-TD
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-TG
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-TN
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-VU
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-WF
# >    using:['GB', 'R.-U.']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'NU']
# >    using:['US', 'É.-U.']
# fr-YT
# >    using:['GB', 'RA']
# >    using:['HK', 'Hong Cong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'an Phalaistín']
# >    using:['UN', 'NA']
# >    using:['US', 'SAM']
# ga
# >    using:['GB', 'RU']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'ONU']
# >    using:['US', 'EUA']
# gl
# >    using:['GB', 'યુ.કે.']
# >    using:['HK', 'હોંગ કોંગ']
# >    using:['MO', 'મકાઉ']
# >    using:['PS', 'પેલેસ્ટાઇન']
# >    using:['UN', 'યૂએન']
# ...
# >    using:['MO', 'ມາກາວ']
# >    using:['PS', 'ປາເລສຕາຍ']
# >    using:['UN', 'ຢູເອັນ']
# >    using:['US', 'ສະຫະລັດຯ']
# lo
# >    using:['GB', 'JK']
# >    using:['HK', 'Honkongas']
# >    using:['MO', 'Makao']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'JT']
# >    using:['US', 'JAV']
# lt
# >    using:['GB', 'Lielbritānija']
# >    using:['HK', 'Honkonga']
# >    using:['MO', 'Makao']
# >    using:['PS', 'Palestīna']
# >    using:['UN', 'ANO']
# >    using:['US', 'ASV']
# lv
# >    using:['GB', 'ОК']
# >    using:['HK', 'Хонг Конг']
# >    using:['MO', 'Макао']
# >    using:['PS', 'Палестина']
# >    using:['UN', 'ОН']
# >    using:['US', 'САД']
# mk
# >    using:['GB', 'യു.കെ.']
# >    using:['HK', 'ഹോങ്കോങ്']
# >    using:['MO', 'മക്കാവു']
# >    using:['PS', 'പലസ്\u200cതീൻ']
# >    using:['UN', 'യുഎൻ']
# >    using:['US', 'യു.എസ്']
# ml
# >    using:['GB', 'ИБ']
# >    using:['HK', 'Хонг Конг']
# >    using:['MO', 'Макао']
# >    using:['PS', 'Палестин']
# >    using:['UN', 'НҮБ']
# >    using:['US', 'АНУ']
# mn
# >    using:['GB', 'यू.के.']
# >    using:['HK', 'हाँगकाँग']
# >    using:['MO', 'मकाओ']
# >    using:['PS', 'पॅलेस्टाईन']
# >    using:['UN', 'यूएन']
# >    using:['US', 'यू.एस.']
# mr
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestin']
# >    using:['UN', 'PBB']
# >    using:['US', 'A.S']
# ms
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestin']
# >    using:['UN', 'PBB']
# >    using:['US', 'A.S']
# ms-BN
# >    using:['GB', 'UK']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestin']
# >    using:['UN', 'PBB']
# >    using:['US', 'A.S']
# ms-SG
# >    using:['GB', 'ယူကေ']
# >    using:['HK', 'ဟောင်ကောင်']
# >    using:['MO', 'မကာအို']
# >    using:['PS', 'ပါလက်စတိုင်း']
# >    using:['UN', 'ကုလသမဂ္ဂ']
# >    using:['US', 'ယူအက်စ်']
# my
# >    using:['GB', 'Storbritannia']
# >    using:['HK', 'Hongkong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'FN']
# >    using:['US', 'USA']
# nb
# >    using:['GB', 'Storbritannia']
# >    using:['HK', 'Hongkong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'FN']
# >    using:['US', 'USA']
# nb-SJ
# >    using:['GB', 'बेलायत']
# >    using:['HK', 'हङकङ']
# >    using:['MO', 'मकाउ']
# >    using:['PS', 'प्यालेसटाइन']
# >    using:['UN', 'यूएन']
# >    using:['US', 'अमेरिका']
# ne
# >    using:['GB', 'बेलायत']
# >    using:['HK', 'हङकङ']
# >    using:['MO', 'मकाउ']
# >    using:['PS', 'प्यालेसटाइन']
# >    using:['UN', 'यूएन']
# >    using:['US', 'अमेरिका']
# ne-IN
# >    using:['GB', 'VK']
# >    using:['HK', 'Hongkong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'VN']
# >    using:['US', 'VS']
# nl
# >    using:['GB', 'VK']
# >    using:['HK', 'Hongkong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'VN']
# >    using:['US', 'VS']
# nl-AW
# >    using:['GB', 'VK']
# >    using:['HK', 'Hongkong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'VN']
# >    using:['US', 'VS']
# nl-BE
# >    using:['GB', 'VK']
# >    using:['HK', 'Hongkong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'VN']
# >    using:['US', 'VS']
# nl-BQ
# >    using:['GB', 'VK']
# >    using:['HK', 'Hongkong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'VN']
# >    using:['US', 'VS']
# nl-CW
# >    using:['GB', 'VK']
# >    using:['HK', 'Hongkong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'VN']
# >    using:['US', 'VS']
# nl-SR
# >    using:['GB', 'VK']
# >    using:['HK', 'Hongkong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'VN']
# >    using:['US', 'VS']
# nl-SX
# >    using:['GB', 'ਯੂ.ਕੇ.']
# >    using:['HK', 'ਹਾਂਗ ਕਾਂਗ']
# >    using:['MO', 'ਮਕਾਉ']
# >    using:['PS', 'ਫਿਲੀਸਤੀਨ']
# >    using:['UN', 'ਯੂ.ਐੱਨ.']
# >    using:['US', 'ਯੂ.ਐੱਸ.']
# pa
# >    using:['GB', 'ਯੂ.ਕੇ.']
# >    using:['HK', 'ਹਾਂਗ ਕਾਂਗ']
# >    using:['MO', 'ਮਕਾਉ']
# >    using:['PS', 'ਫਿਲੀਸਤੀਨ']
# >    using:['UN', 'ਯੂ.ਐੱਨ.']
# >    using:['US', 'ਯੂ.ਐੱਸ.']
# pa-Guru
# >    using:['GB', 'Wlk. Bryt.']
# >    using:['HK', 'Hongkong']
# >    using:['MO', 'Makau']
# >    using:['PS', 'Palestyna']
# >    using:['UN', 'ONZ']
# >    using:['US', 'USA']
# pl
# >    using:['GB', 'Reino Unido']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'ONU']
# >    using:['US', 'EUA']
# pt
# >    using:['GB', 'GB']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'ONU']
# >    using:['US', 'EUA']
# pt-AO
# >    using:['GB', 'GB']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'ONU']
# >    using:['US', 'EUA']
# pt-CH
# >    using:['GB', 'GB']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'ONU']
# >    using:['US', 'EUA']
# pt-CV
# >    using:['GB', 'GB']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'ONU']
# >    using:['US', 'EUA']
# pt-GQ
# >    using:['GB', 'GB']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'ONU']
# >    using:['US', 'EUA']
# pt-GW
# >    using:['GB', 'GB']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'ONU']
# >    using:['US', 'EUA']
# pt-LU
# >    using:['GB', 'GB']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'ONU']
# >    using:['US', 'EUA']
# pt-MO
# >    using:['GB', 'GB']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'ONU']
# >    using:['US', 'EUA']
# pt-MZ
# >    using:['GB', 'GB']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'ONU']
# >    using:['US', 'EUA']
# pt-PT
# >    using:['GB', 'GB']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'ONU']
# >    using:['US', 'EUA']
# pt-ST
# >    using:['GB', 'GB']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'ONU']
# >    using:['US', 'EUA']
# pt-TL
# >    using:['GB', 'Regatul Unit']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'ONU']
# >    using:['US', 'S.U.A.']
# ro
# >    using:['GB', 'Regatul Unit']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'ONU']
# >    using:['US', 'S.U.A.']
# ro-MD
# >    using:['GB', 'GB']
# >    using:['HK', 'HK']
# >    using:['MO', 'MO']
# >    using:['PS', 'PS']
# >    using:['US', 'US']
# root
# >    using:['GB', 'Британия']
# >    using:['HK', 'Гонконг']
# >    using:['MO', 'Макао']
# >    using:['PS', 'Палестина']
# >    using:['UN', 'ООН']
# >    using:['US', 'США']
# ru
# >    using:['GB', 'Британия']
# >    using:['HK', 'Гонконг']
# >    using:['MO', 'Макао']
# >    using:['PS', 'Палестина']
# >    using:['UN', 'ООН']
# >    using:['US', 'США']
# ru-BY
# >    using:['GB', 'Британия']
# >    using:['HK', 'Гонконг']
# >    using:['MO', 'Макао']
# >    using:['PS', 'Палестина']
# >    using:['UN', 'ООН']
# >    using:['US', 'США']
# ru-KG
# >    using:['GB', 'Британия']
# >    using:['HK', 'Гонконг']
# >    using:['MO', 'Макао']
# >    using:['PS', 'Палестина']
# >    using:['UN', 'ООН']
# >    using:['US', 'США']
# ru-KZ
# >    using:['GB', 'Британия']
# >    using:['HK', 'Гонконг']
# >    using:['MO', 'Макао']
# >    using:['PS', 'Палестина']
# >    using:['UN', 'ООН']
# >    using:['US', 'США']
# ru-MD
# >    using:['GB', 'Британия']
# >    using:['HK', 'Гонконг']
# >    using:['MO', 'Макао']
# >    using:['PS', 'Палестина']
# >    using:['UN', 'ООН']
# >    using:['US', 'США']
# ru-UA
# >    using:['GB', 'එ.රා']
# >    using:['HK', 'හොංකොං']
# >    using:['MO', 'මකාවු']
# >    using:['PS', 'පලස්තීනය']
# >    using:['UN', 'එක්සත් ජාතීන්']
# >    using:['US', 'එ.ජ']
# si
# >    using:['GB', 'UK']
# >    using:['HK', 'Hongkong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestínska samospráva']
# >    using:['UN', 'OSN']
# >    using:['US', 'USA']
# sk
# >    using:['GB', 'ZK']
# >    using:['HK', 'Hongkong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'ZN']
# >    using:['US', 'ZDA']
# sl
# >    using:['GB', 'Mbretëria e Bashkuar']
# >    using:['HK', 'Hong-Kong']
# >    using:['MO', 'Makao']
# >    using:['PS', 'Palestinë']
# >    using:['UN', 'Kombet e Bashkuara']
# >    using:['US', 'SHBA']
# sq
# >    using:['GB', 'Mbretëria e Bashkuar']
# >    using:['HK', 'Hong-Kong']
# >    using:['MO', 'Makao']
# >    using:['PS', 'Palestinë']
# >    using:['UN', 'Kombet e Bashkuara']
# >    using:['US', 'SHBA']
# sq-MK
# >    using:['GB', 'Mbretëria e Bashkuar']
# >    using:['HK', 'Hong-Kong']
# >    using:['MO', 'Makao']
# >    using:['PS', 'Palestinë']
# >    using:['UN', 'Kombet e Bashkuara']
# >    using:['US', 'SHBA']
# sq-XK
# >    using:['GB', 'УК']
# >    using:['HK', 'Хонгконг']
# >    using:['MO', 'Макао']
# >    using:['PS', 'Палестина']
# >    using:['UN', 'УН']
# >    using:['US', 'САД']
# sr
# >    using:['GB', 'УК']
# >    using:['HK', 'Хонгконг']
# >    using:['MO', 'Макао']
# >    using:['PS', 'Палестина']
# >    using:['UN', 'УН']
# >    using:['US', 'САД']
# sr-Cyrl
# >    using:['GB', 'УК']
# >    using:['HK', 'Хонгконг']
# >    using:['MO', 'Макао']
# >    using:['PS', 'Палестина']
# >    using:['UN', 'УН']
# >    using:['US', 'САД']
# sr-Cyrl-BA
# >    using:['GB', 'УК']
# >    using:['HK', 'Хонгконг']
# >    using:['MO', 'Макао']
# >    using:['PS', 'Палестина']
# >    using:['UN', 'УН']
# >    using:['US', 'САД']
# sr-Cyrl-ME
# >    using:['GB', 'УК']
# >    using:['HK', 'Хонгконг']
# >    using:['MO', 'Макао']
# >    using:['PS', 'Палестина']
# >    using:['UN', 'УН']
# >    using:['US', 'САД']
# sr-Cyrl-XK
# >    using:['GB', 'UK']
# >    using:['HK', 'Hongkong']
# >    using:['MO', 'Makao']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'UN']
# >    using:['US', 'SAD']
# sr-Latn
# >    using:['GB', 'UK']
# >    using:['HK', 'Hongkong']
# >    using:['MO', 'Makao']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'UN']
# >    using:['US', 'SAD']
# sr-Latn-BA
# >    using:['GB', 'UK']
# >    using:['HK', 'Hongkong']
# >    using:['MO', 'Makao']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'UN']
# >    using:['US', 'SAD']
# sr-Latn-ME
# >    using:['GB', 'UK']
# >    using:['HK', 'Hongkong']
# >    using:['MO', 'Makao']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'UN']
# >    using:['US', 'SAD']
# sr-Latn-XK
# >    using:['GB', 'Storbritannien']
# >    using:['HK', 'Hongkong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'FN']
# >    using:['US', 'USA']
# sv
# >    using:['GB', 'Storbritannien']
# >    using:['HK', 'Hongkong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'FN']
# >    using:['US', 'USA']
# sv-AX
# >    using:['GB', 'Storbritannien']
# >    using:['HK', 'Hongkong']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'FN']
# >    using:['US', 'USA']
# sv-FI
# >    using:['GB', 'Uingereza']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'Umoja wa Mataifa']
# >    using:['US', 'US']
# sw
# >    using:['GB', 'Uingereza']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'Umoja wa Mataifa']
# >    using:['US', 'US']
# sw-CD
# >    using:['GB', 'Uingereza']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'Umoja wa Mataifa']
# >    using:['US', 'US']
# sw-KE
# >    using:['GB', 'Uingereza']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Macau']
# >    using:['PS', 'Palestina']
# >    using:['UN', 'Umoja wa Mataifa']
# >    using:['US', 'US']
# sw-UG
# >    using:['GB', 'யூகே']
# >    using:['HK', 'ஹாங்காங்']
# >    using:['MO', 'மகாவ்']
# >    using:['PS', 'பாலஸ்தீனம்']
# >    using:['UN', 'ஐநா']
# >    using:['US', 'யூஎஸ்']
# ta
# >    using:['GB', 'யூகே']
# >    using:['HK', 'ஹாங்காங்']
# >    using:['MO', 'மகாவ்']
# >    using:['PS', 'பாலஸ்தீனம்']
# >    using:['UN', 'ஐநா']
# >    using:['US', 'யூஎஸ்']
# ta-LK
# >    using:['GB', 'யூகே']
# >    using:['HK', 'ஹாங்காங்']
# >    using:['MO', 'மகாவ்']
# >    using:['PS', 'பாலஸ்தீனம்']
# >    using:['UN', 'ஐநா']
# >    using:['US', 'யூஎஸ்']
# ta-MY
# >    using:['GB', 'யூகே']
# >    using:['HK', 'ஹாங்காங்']
# >    using:['MO', 'மகாவ்']
# >    using:['PS', 'பாலஸ்தீனம்']
# >    using:['UN', 'ஐநா']
# >    using:['US', 'யூஎஸ்']
# ta-SG
# >    using:['GB', 'యు.కె.']
# >    using:['HK', 'హాంకాంగ్']
# >    using:['MO', 'మకావ్']
# >    using:['PS', 'పాలస్తీనా']
# >    using:['UN', 'యు.ఎన్']
# >    using:['US', 'యు.ఎస్.']
# te
# >    using:['GB', 'อังกฤษ']
# >    using:['HK', 'ฮ่องกง']
# >    using:['MO', 'มาเก๊า']
# >    using:['PS', 'ปาเลสไตน์']
# >    using:['UN', 'สหประชาชาติ']
# >    using:['US', 'สหรัฐฯ']
# th
# >    using:['GB', 'Pilitānia']
# >    using:['HK', 'Hongi Kongi']
# >    using:['MO', 'Makau']
# >    using:['PS', 'Palesitaine']
# >    using:['US', 'ʻAmelika']
# to
# >    using:['GB', 'BK']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Makao']
# >    using:['PS', 'Filistin']
# >    using:['UN', 'BM']
# >    using:['US', 'ABD']
# tr
# >    using:['GB', 'BK']
# >    using:['HK', 'Hong Kong']
# >    using:['MO', 'Makao']
# >    using:['PS', 'Filistin']
# >    using:['UN', 'BM']
# >    using:['US', 'ABD']
# tr-CY
# >    using:['GB', 'Велика Британія']
# >    using:['HK', 'Гонконг']
# >    using:['MO', 'Макао']
# >    using:['PS', 'Палестина']
# >    using:['UN', 'ООН']
# >    using:['US', 'США']
# uk
# >    using:['GB', 'یو کے']
# >    using:['HK', 'ہانگ کانگ']
# >    using:['MO', 'مکاؤ']
# >    using:['PS', 'فلسطین']
# >    using:['UN', 'اقوام متحدہ']
# >    using:['US', 'امریکا']
# ur
# >    using:['GB', 'یو کے']
# >    using:['HK', 'ہانگ کانگ']
# >    using:['MO', 'مکاؤ']
# >    using:['PS', 'فلسطین']
# >    using:['UN', 'اقوام متحدہ']
# >    using:['US', 'امریکا']
# ur-IN
# >    using:['GB', 'Britaniya']
# >    using:['HK', 'Gonkong']
# >    using:['MO', 'Makao']
# >    using:['PS', 'Falastin']
# >    using:['UN', 'BMT']
# >    using:['US', 'AQSH']
# uz
# >    using:['GB', 'Britaniya']
# >    using:['HK', 'Gonkong']
# >    using:['MO', 'Makao']
# >    using:['PS', 'Falastin']
# >    using:['UN', 'BMT']
# >    using:['US', 'AQSH']
# uz-Latn
# >    using:['GB', 'Vương quốc Anh']
# >    using:['HK', 'Hồng Kông']
# >    using:['MO', 'Macao']
# >    using:['PS', 'Palestine']
# >    using:['UN', 'Liên hiệp quốc']
# >    using:['US', 'Hoa Kỳ']
# vi
# >    using:['GB', '英國']
# >    using:['HK', '香港']
# >    using:['MO', '澳門']
# >    using:['PS', '巴勒斯坦']
# >    using:['US', '美國']
# yue
# >    using:['GB', '英國']
# >    using:['HK', '香港']
# >    using:['MO', '澳門']
# >    using:['PS', '巴勒斯坦']
# >    using:['US', '美國']
# yue-Hant
# >    using:['GB', '英国']
# >    using:['HK', '香港']
# >    using:['MO', '澳门']
# >    using:['PS', '巴勒斯坦']
# >    using:['UN', '联合国']
# >    using:['US', '美国']
# zh
# >    using:['GB', '英国']
# >    using:['HK', '香港']
# >    using:['MO', '澳门']
# >    using:['PS', '巴勒斯坦']
# >    using:['UN', '联合国']
# >    using:['US', '美国']
# zh-Hans
# >    using:['GB', '英国']
# >    using:['HK', '香港']
# >    using:['MO', '澳门']
# >    using:['PS', '巴勒斯坦']
# >    using:['UN', '联合国']
# >    using:['US', '美国']
# zh-Hans-HK
# >    using:['GB', '英国']
# >    using:['HK', '香港']
# >    using:['MO', '澳门']
# >    using:['PS', '巴勒斯坦']
# >    using:['UN', '联合国']
# >    using:['US', '美国']
# zh-Hans-MO
# >    using:['GB', '英国']
# >    using:['HK', '香港']
# >    using:['MO', '澳门']
# >    using:['PS', '巴勒斯坦']
# >    using:['UN', '联合国']
# >    using:['US', '美国']
# zh-Hans-SG
# >    using:['GB', '英國']
# >    using:['HK', '香港']
# >    using:['MO', '澳門']
# >    using:['PS', '巴勒斯坦']
# >    using:['UN', '聯合國']
# >    using:['US', '美國']
# zh-Hant
# >    using:['GB', '英國']
# >    using:['HK', '香港']
# >    using:['MO', '澳門']
# >    using:['PS', '巴勒斯坦']
# >    using:['UN', '聯合國']
# >    using:['US', '美國']
# zh-Hant-HK
# >    using:['GB', '英國']
# >    using:['HK', '香港']
# >    using:['MO', '澳門']
# >    using:['PS', '巴勒斯坦']
# >    using:['UN', '聯合國']
# >    using:['US', '美國']
# zh-Hant-MO
# >    using:['GB', 'i-U.K.']
# >    using:['HK', 'i-Hong Kong']
# >    using:['MO', 'i-Macau']
# >    using:['PS', 'i-Palestine']
# >    using:['UN', 'ifulegi']
# >    using:['US', 'i-U.S']
# zu

# %%
## Outpuing Lists
for lc, outputlist in outputlist_territories.items():
    ### Create directory if not exists
    directory = os.path.join("..", dir_outcome, lc)
    if not os.path.exists(directory):
        os.makedirs(directory)
    outputfn_json = os.path.join (directory, outputfn_JSON)
    outputfn_html = os.path.join (directory, outputfn_HTML)
    
    with open(outputfn_json, 'w', encoding="utf-8") as outfile:
        outfile.write("{}".format(outputlist).replace("'",'"'))
        #json.dump("{}".format(outputlist), outfile)
    with open(outputfn_html, 'w', encoding="utf-8") as outfile:
        outputtxt = '''<datalist id="countries">'''+"".join(['''<option value="{v}">'''.format(v=x) for x in outputlist])+'''</datalist>'''
        outfile.write(outputtxt)
